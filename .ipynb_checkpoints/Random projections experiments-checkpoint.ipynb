# %%
# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.preprocessing    import normalize

# %%
n                 = 10000
dim_emb           = 1000
max_rand_proj_dim = 200
X                 = np.random.randn(n, dim_emb)

# %%
def run_experiment(X, dist_fun, normalize_proj_mat, normal_rand_proj, max_rand_proj_dim):
    dist_orig      = dist_fun(X)
    mean_diff      = []
    rand_proj_dims = np.arange(1, max_rand_proj_dim)
    
    for rand_proj_dim in rand_proj_dims:
        if normal_rand_proj:
            rand_proj_mat = np.random.randn(dim_emb, rand_proj_dim)
        else:
            rand_proj_mat = np.random.random((dim_emb, rand_proj_dim))            
        rand_proj_mat = normalize(rand_proj_mat) if normalize_proj_mat else rand_proj_mat
        rand_proj     = np.dot(X, rand_proj_mat)
        dist_proj     = dist_fun(rand_proj)
        mean_diff.append(np.mean(np.abs(dist_orig - dist_proj)))

    return rand_proj_dims, np.array(mean_diff)

# %%
proj_dims, exp_result = run_experiment(
    X                  = X, 
    dist_fun           = cosine_similarity, 
    normalize_proj_mat = False,
    normal_rand_proj   = False, 
    max_rand_proj_dim  = max_rand_proj_dim
)
plt.plot(proj_dims, exp_result)
_ = plt.title('cos_sim, uniform proj mat, raw projections')

# %%
proj_dims, exp_result = run_experiment(
    X                  = X, 
    dist_fun           = cosine_similarity, 
    normalize_proj_mat = False,
    normal_rand_proj   = True, 
    max_rand_proj_dim  = max_rand_proj_dim
)
plt.plot(proj_dims, exp_result)
_ = plt.title('cos_sim, uniform proj mat, normalized projections')

# %%
proj_dims, exp_result = run_experiment(
    X                  = X, 
    dist_fun           = cosine_similarity, 
    normalize_proj_mat = True,
    normal_rand_proj   = False, 
    max_rand_proj_dim  = max_rand_proj_dim
)
plt.plot(proj_dims, exp_result)
_ = plt.title('cos_sim, normal proj mat, raw projections')

# %%
proj_dims, exp_result = run_experiment(
    X                  = X, 
    dist_fun           = cosine_similarity, 
    normalize_proj_mat = True,
    normal_rand_proj   = True, 
    max_rand_proj_dim  = max_rand_proj_dim
)
plt.plot(proj_dims, exp_result)
_ = plt.title('cos_sim, normal proj mat, normalized projections')

# %%
proj_dims, exp_result = run_experiment(
    X                  = X, 
    dist_fun           = euclidean_distances, 
    normalize_proj_mat = False, 
    normal_rand_proj   = False, 
    max_rand_proj_dim  = max_rand_proj_dim
)
plt.plot(proj_dims, exp_result)
_ = plt.title('eucl_dist, uniform proj mat, raw projections')

# %%
proj_dims, exp_result = run_experiment(
    X                  = X, 
    dist_fun           = euclidean_distances, 
    normalize_proj_mat = False, 
    normal_rand_proj   = True, 
    max_rand_proj_dim  = max_rand_proj_dim
)
plt.plot(proj_dims, exp_result)
_ = plt.title('eucl_dist, uniform proj mat, normalized projections')

# %%
proj_dims, exp_result = run_experiment(
    X                  = X, 
    dist_fun           = euclidean_distances, 
    normalize_proj_mat = True, 
    normal_rand_proj   = False, 
    max_rand_proj_dim  = max_rand_proj_dim
)
plt.plot(proj_dims, exp_result)
_ = plt.title('eucl_dist, normal proj mat, raw projections')

# %%
proj_dims, exp_result = run_experiment(
    X                  = X, 
    dist_fun           = euclidean_distances, 
    normalize_proj_mat = True, 
    normal_rand_proj   = True, 
    max_rand_proj_dim  = max_rand_proj_dim
)
plt.plot(proj_dims, exp_result)
_ = plt.title('eucl_dist, normal proj mat, normalized projections')
